# %% [markdown]
# # *LLM CALL*

# %%
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = OllamaLLM(model="llama3")

prompt = ChatPromptTemplate.from_template("""
You are a senior DevOps engineer.

Answer clearly and in simple language.

Question:
{question}
""")

parser = StrOutputParser()

chain = prompt | llm | parser

response = chain.invoke({
    "question": "Explain Kubernetes and why companies use it."
})

print(response)
# Out:
# Kubernetes is an open-source platform that helps manage and deploy containerized applications. Think of containers like little boxes that package up your code, libraries, and dependencies, making it easy to run the same application on different environments (like development, testing, or production).
#
# In the past, setting up and managing these containers was a pain. You had to manually configure servers, handle scaling, and ensure everything worked together seamlessly. That's where Kubernetes comes in.
#
# Kubernetes provides a way to orchestrate (or manage) your containerized applications. It makes sure that:
#
# 1. **Containers are deployed correctly**: Kubernetes ensures that each container has the necessary resources, like CPU and memory, to run efficiently.
# 2. **Containers are scaled**: You can easily scale your application up or down based on demand, ensuring that your users have a great experience.
# 3. **Containers communicate**: Kubernetes provides networking between containers, so they can talk to each other and share data.
#
# Companies use Kubernetes for several reasons:
#
# 1. **Efficient resource utilization**: Kubernetes helps optimize server resources, reducing waste and improving overall performance.
# 2. **Faster deployment**: With Kubernetes, you can deploy new applications or updates much faster, thanks to its automated processes.
# 3. **Scalability**: As your application grows, Kubernetes makes it easy to scale horizontally (add more instances) or vertically (increase resources).
# 4. **High availability**: Kubernetes ensures that your application is always available, by automatically restarting containers if one fails.
# 5. **Portability**: Since Kubernetes abstracts away the underlying infrastructure, you can easily move your applications between environments (like from dev to prod).
#
# In short, Kubernetes helps companies build and manage scalable, efficient, and highly available containerized applications. That's why it's become a popular choice for many organizations!
